# %% [markdown]
# Sigmoid Function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Converts input to near 0 or 1, allowing for binary classfication.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
